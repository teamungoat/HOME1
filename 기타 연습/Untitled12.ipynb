# %%
#1. 개의 숫자를 입력으로 받고 3개의 숫자 중에 중간값을 가지는 숫자를 출력하세요. ex1) 2, 5, 3 => 3 ex2) 4, 6, 4 => 4
num1, num2, num3 = input("3자리를 입력하시오").split(" ")
num1
num2
num3
num_list=[int(num1),int(num2),int(num3)]
num_list.sort()
num_list
print(num_list[1])

# %%
# 2.
# 숫자 형태의 문자열을 콤마가 포함된 금액 표기식 문자열로 바꾸어주는 프로그램을 작성하시오.

# ※ 단, 프로그래밍 언어에서 지원하는 금액변환 라이브러리는 사용하지 말것

# 예)

# 숫자	금액
# 1000	1,000
# 20000000	20,000,000
# -3245.24	-3,245.24
