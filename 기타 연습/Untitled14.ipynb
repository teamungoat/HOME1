# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pd.read_csv('/content/drive/MyDrive/dl_data/title.crew.tsv', sep='\t')
# Out:
#              tconst            directors  \
# 0         tt0000001            nm0005690
# 1         tt0000002            nm0721526
# 2         tt0000003            nm0721526
# 3         tt0000004            nm0721526
# 4         tt0000005            nm0005690
# ...             ...                  ...
# 10231611  tt9916848            nm1485677
# 10231612  tt9916850            nm1485677
# 10231613  tt9916852            nm1485677
# 10231614  tt9916856           nm10538645
# 10231615  tt9916880  nm0584014,nm0996406
#
#                                                     writers
# 0                                                        \N
# 1                                                        \N
# 2                                                        \N
# 3                                                        \N
# 4                                                        \N
# ...                                                     ...
# ...

# %%
pip install konlpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 23.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 38.2 MB/s eta 0:00:00
# ...
