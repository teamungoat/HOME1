# %%
import random

lotolists = []
for i in range(6):
    lottolist = []
    while len(lottolist) < 6:
        number = random.randint(1,45)
        if number not in lottolist:
            lottolist.append(number)
    lottolists.append(lottolist)
lottolists
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4f1b06aa0994> in <cell line: 4>()
#       8         if number not in lottolist:
#       9             lottolist.append(number)
# ---> 10     lottolists.append(lottolist)
#      11 lottolists
#
# NameError: name 'lottolists' is not defined
