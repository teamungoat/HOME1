# %%
# 1. 영어권 뉴스 사이트에 접속하여 기사를 스크랩한 다음, 공백 및 마침표 등으로 구분하여 리스트에 저장하세요.
pip install selenium
# Out:
#   File "<ipython-input-11-b1ab81a29d9b>", line 2
#     pip install selenium
#         ^
# SyntaxError: invalid syntax
