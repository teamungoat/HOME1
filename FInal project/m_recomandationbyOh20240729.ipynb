# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.4)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (24.1)
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 40.3 MB/s eta 0:00:00
# Downloading JPype1-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (488 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 30.6 MB/s eta 0:00:00
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.5.0 konlpy-0.6.0

# %%
# !pip install pandas openpyxl xlrd konlpy scikit-learn
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.5)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.10/dist-packages (2.0.1)
# Requirement already satisfied: konlpy in /usr/local/lib/python3.10/dist-packages (0.6.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.5.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (24.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (6,992 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 123589 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/fixed_movie_data')
df
# Out:
#        movie_id         kind  \
# 0             0          영화명
# 1             0           장르
# 2             0           감독
# 3             0           각본
# 4             0           제작
# ...         ...          ...
# 16210      1253        상영 시간
# 16211      1253  대한민국 총 관객 수
# 16212      1253         시놉시스
# 16213      1254          영화명
# 16214      1254         시놉시스
#
#                                                  content
# 0                                                 이매큘레이트
# 1                                                공포, 스릴러
# 2                                                 마이클 모한
# 3                                                 앤드류 로벨
# 4            데이빗 버나드, 요나탄 다비노, 마이클 하임러, 테디 슈워츠먼, 시드니 스위니
# ...                                                  ...
# 16210                                               114분
# 16211                                    1,006,947명 (최종)
# 16212  심장은 하나, 살려야 할 사람은 둘. 당신이라면 어떻게 하겠어?한 중년 여성이 뇌사...
# 16213                                                상하이
# 16214  1941년, 진주만 공격의 거대한 음모가 밝혀진다1941년, 진주만 공격 60일 전...
#
# [16215 rows x 3 columns]

# %%
df.drop(columns=['movie_id'], inplace=True)

# %%
list(df.iloc[0:23]['kind'])
# Out:
# ['영화명',
#  '장르',
#  '감독',
#  '각본',
#  '제작',
#  '원작',
#  '출연',
#  '촬영',
#  '편집',
#  '미술',
#  '음악',
#  '음향',
#  '촬영 기간',
#  '수입사',
#  '배급사',
#  '개봉일',
#  '상영 시간',
#  '제작비',
#  '월드 박스오피스',
#  '북미 박스오피스',
#  '대한민국 총 관객 수',
#  '상영 등급',
#  '시놉시스']

# %%
# 파일 경로
file_path = '/content/fixed_movie_data'

# 파일 불러오기
df = pd.read_csv(file_path)

# 'content' 열의 모든 값을 문자열로 변환
df['content'] = df['content'].astype(str)

# 'movie_id'와 'kind'로 그룹화하고, 중복 값을 결합하여 집계
df_aggregated = df.groupby(['movie_id', 'kind'])['content'].agg(lambda x: ' / '.join(x)).reset_index()

# 집계된 DataFrame을 피벗
pivot_df_aggregated = df_aggregated.pivot(index='movie_id', columns='kind', values='content').reset_index()

# 멀티레벨 열 이름 제거
pivot_df_aggregated.columns.name = None


pivot_df_aggregated.tail()
# Out:
#       movie_id                                                 각본       감독  \
# 1250      1250                                                nan   앤드류 니콜
# 1251      1251                                크리스토퍼 마커스스티븐 맥필리[1]    조 존스턴
# 1252      1252  존 R. 스미스롭 스프래클링켈리 애즈베리마크 버턴앤디 라일리케빈 세실에밀리 쿡캐시 ...  켈리 애즈베리
# 1253      1253                                                NaN      NaN
# 1254      1254                                                NaN      NaN
#
#                                           개봉일       대한민국 총 관객 수           미술  \
# 1250                                      NaN               NaN          NaN
# 1251                2011년 7월 22일 2011년 7월 28일     514,417명 (최종)  숀 하워스릭 하인리히
# 1252   2011년 2월 11일 2011년 2월 11일 2011년 4월 14일          221,195명          NaN
# 1253                                      NaN   1,006,947명 (최종)     김진철  전진원
# 1254                                      NaN               NaN          NaN
#
#                            배급사           북미 박스오피스         상영 등급  \
# 1250                       NaN        $37,520,095    12세 이상 관람가
# 1251    파라마운트 픽처스 CJ ENM MOVIE  $176,654,505 (최종)   12세 이상 관람가
# 1252   월트 디즈니 스튜디오스 모션 픽처스 쇼박스        $94,000,000        전체 관람가
# 1253                                          NaN           NaN
# 1254                       NaN                NaN           NaN
#
#                    상영 시간  ...           월드 박스오피스  \
# 1250  109분 (1시간 49분 11초)  ...       $173,930,596
# 1251       124분 (2시간 4분)  ...  $370,569,774 (최종)
# 1252                 84분  ...       $193,967,670
# 1253                114분  ...                NaN
# 1254                 NaN  ...                NaN
#
#                                  음악        음향  \
# 1250                            NaN       NaN
# 1251                    앨런 실베스트리[2]       NaN
# 1252  엘튼 존버니 토핀크리스 P. 베이컨제임스 뉴튼 하워드       NaN
# 1253                       방준석  복숭아  이승철  이성진
# 1254                            NaN       NaN
#
#                                       장르                        제작  \
# 1250                   SF, 사이버펑크, 액션, 범죄                       NaN
# 1251  슈퍼히어로, 전쟁, SF, 액션, 어드벤처, 가상 역사 판타지                    케빈 파이기
# 1252                애니메이션, 코미디, 판타지, 뮤지컬  데이비드 퍼니시스티브 해밀턴 쇼이고르 카이트
# 1253                                 드라마                       최건용
# 1254                                 NaN                       NaN
#
#                제작비      촬영                           촬영 기간          출연  \
# 1250     4,000만 달러  로저 디킨스                             NaN         NaN
# 1251  1억 4,000만 달러   셸리 존슨  2010년 6월 28일 ~ 2010년 12월 3일[3]         NaN
# 1252     3,600만 달러     NaN                             NaN         NaN
# 1253           NaN     정해근                             NaN  김윤진  박해일 외
# 1254           NaN     NaN                             NaN         NaN
#
#                 편집
# 1250        잭 스탠버그
# 1251  제프리 포드로버트 댈바
# 1252           NaN
# 1253           조민석
# 1254           NaN
#
# [5 rows x 24 columns]

# %%
pivot_df_aggregated.columns
# Out:
# Index(['movie_id', '각본', '감독', '개봉일', '대한민국 총 관객 수', '미술', '배급사', '북미 박스오피스',
#        '상영 등급', '상영 시간', '수입사', '시놉시스', '영화명', '원작', '월드 박스오피스', '음악', '음향',
#        '장르', '제작', '제작비', '촬영', '촬영 기간', '출연', '편집'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', None)

# %%
pivot_df_aggregated
# Out:
#       movie_id                                                 각본         감독  \
# 0            0                                             앤드류 로벨     마이클 모한
# 1            1                                    로즈 글래스베로니카 토필스카  로즈 글래스[1]
# 2            2                                                박계옥        양윤호
# 3            3                                리처드 링클레이터에단 호크줄리 델피  리처드 링클레이터
# 4            4                                                NaN        NaN
# ...        ...                                                ...        ...
# 1250      1250                                                nan     앤드류 니콜
# 1251      1251                                크리스토퍼 마커스스티븐 맥필리[1]      조 존스턴
# 1252      1252  존 R. 스미스롭 스프래클링켈리 애즈베리마크 버턴앤디 라일리케빈 세실에밀리 쿡캐시 ...    켈리 애즈베리
# 1253      1253                                                NaN        NaN
# 1254      1254                                                NaN        NaN
#
#                                                개봉일       대한민국 총 관객 수  \
# 0                     2024년 3월 22일 2024년 7월 17일[1]           15,361명
# 1        2024년 3월 15일[3]  2024년 5월 3일 2024년 7월 10일               NaN
# 2                                    1998년 11월 28일               NaN
# 3      2004년 7월 30일 2004년 10월 22일 2016년 8월 31일 재개봉               NaN
# 4                                              NaN               NaN
# ...                                            ...               ...
# 1250                                           NaN               NaN
# 1251                     2011년 7월 22일 2011년 7월 28일     514,417명 (최종)
# 1252        2011년 2월 11일 2011년 2월 11일 2011년 4월 14일          221,195명
# 1253                                           NaN   1,006,947명 (최종)
# 1254                                           NaN               NaN
#
#                미술                       배급사                      북미 박스오피스  \
# 0             nan             Neon (주)디스테이션                             ?
# 1             NaN     A24 라이온스게이트 스튜디오디에이치엘  $8,335,797 (2024년 6월 22일 기준)
# 2             강승용               20세기 폭스 코리아                           NaN
# 3             NaN      워너 인디펜던트 픽처스 THE 픽쳐스                           NaN
# 4             NaN                       NaN                           NaN
# ...           ...                       ...                           ...
# 1250          NaN                       NaN                   $37,520,095
# 1251  숀 하워스릭 하인리히    파라마운트 픽처스 CJ ENM MOVIE             $176,654,505 (최종)
# 1252          NaN   월트 디즈니 스튜디오스 모션 픽처스 쇼박스                   $94,000,000
# 1253     김진철  전진원                                                     NaN
# 1254          NaN                       NaN                           NaN
#
#              상영 등급               상영 시간            수입사  \
# 0       15세 이상 관람가   89분 (1시간 28분 36초)         엔케이컨텐츠
# 1         청소년 관람불가  104분 (1시간 43분 48초)      스튜디오디에이치엘
# 2       15세 이상 관람가       90분 (1시간 47분)            NaN
# 3       15세 이상 관람가                 80분        명보아트시네마
# 4              NaN                 NaN            NaN
# ...            ...                 ...            ...
# 1250    12세 이상 관람가  109분 (1시간 49분 11초)            NaN
# 1251   12세 이상 관람가        124분 (2시간 4분)   CJ ENM MOVIE
# 1252        전체 관람가                 84분            NaN
# 1253           NaN                114분            NaN
# 1254           NaN                 NaN            NaN
#
#                                                    시놉시스  \
# 0     순수하고 신실한 믿음을 가진 수녀 '세실리아'(시드니 스위니).어느 비밀스러운 수녀...
# 1     “멍청아, XX 사랑한다구!!”1989년, 체육관 매니저로 일상을 보내던 무기력한 ...
# 2     영생 고등학교 3학년 10반, 문제반으로 낙인 찍힌 이 반에 새로운 담임 황기풍(차...
# 3     비엔나에서의 꿈같은 하루, 6개월 후의 어긋난 약속…그리고 9년이 지난 오늘, 파리...
# 4     홋카이도의 하코다테에 있는 도검 재벌의 깊은 창고에 괴도 키드로부터의 예고장이 도착...
# ...                                                 ...
# 1250  커피 1잔.. 4분, 권총 1정.. 3년, 스포츠카 1대.. 59년!모든 비용은 시...
# 1251  세계 전쟁으로 암흑에 빠진 시기, 한 남자가 군 입대를 자원한다. 그의 이름은 ‘스...
# 1252  링컨 대통령의 목숨을 앗아간 한 발의 총성! 암살에 공모한 8명 중 1명은 두 자녀...
# 1253  심장은 하나, 살려야 할 사람은 둘. 당신이라면 어떻게 하겠어?한 중년 여성이 뇌사...
# 1254  1941년, 진주만 공격의 거대한 음모가 밝혀진다1941년, 진주만 공격 60일 전...
#
#                         영화명                                   원작  \
# 0                    이매큘레이트                                  nan
# 1                러브 라이즈 블리딩                                  NaN
# 2                         짱                                  NaN
# 3                     비포 선셋                                  NaN
# 4     명탐정 코난: 100만 달러의 펜타그램                                  NaN
# ...                     ...                                  ...
# 1250                   인 타임                                  NaN
# 1251                퍼스트 어벤져  조 사이먼, 잭 커비 《캡틴 아메리카 코믹스 #1 (1940)》
# 1252               노미오와 줄리엣                윌리엄 셰익스피어, 《로미오와 줄리엣》
# 1253                 심장이 뛴다                                  NaN
# 1254                    상하이                                  NaN
#
#                            월드 박스오피스                             음악        음향  \
# 0                                 ?                          윌 베이츠        의상
# 1     $11,826,868 (2024년 6월 22일 기준)                      클린트 맨셀[2]       NaN
# 2                               NaN                      최만식 / 최만식       NaN
# 3                               NaN                            NaN       NaN
# 4                               NaN                            NaN       NaN
# ...                             ...                            ...       ...
# 1250                   $173,930,596                            NaN       NaN
# 1251              $370,569,774 (최종)                    앨런 실베스트리[2]       NaN
# 1252                   $193,967,670  엘튼 존버니 토핀크리스 P. 베이컨제임스 뉴튼 하워드       NaN
# 1253                            NaN                       방준석  복숭아  이승철  이성진
# 1254                            NaN                            NaN       NaN
#
#                                       장르  \
# 0                                공포, 스릴러
# 1                             범죄, 멜로/로맨스
# 2                      느와르, 드라마, 액션, 코미디
# 3                                드라마, 멜로
# 4                                    NaN
# ...                                  ...
# 1250                   SF, 사이버펑크, 액션, 범죄
# 1251  슈퍼히어로, 전쟁, SF, 액션, 어드벤처, 가상 역사 판타지
# 1252                애니메이션, 코미디, 판타지, 뮤지컬
# 1253                                 드라마
# 1254                                 NaN
#
#                                                제작           제작비         촬영  \
# 0     데이빗 버나드, 요나탄 다비노, 마이클 하임러, 테디 슈워츠먼, 시드니 스위니            달러  엘리샤 크리스티안
# 1                                  안드레아 콘웰올리버 캐스먼             -      벤 포즈먼
# 2                                    이혁기한성구최성식최성수           NaN        김윤수
# 3                                        앤 워커-맥베이           NaN      리 대니얼
# 4                                             NaN           NaN        NaN
# ...                                           ...           ...        ...
# 1250                                          NaN     4,000만 달러     로저 디킨스
# 1251                                       케빈 파이기  1억 4,000만 달러      셸리 존슨
# 1252                     데이비드 퍼니시스티브 해밀턴 쇼이고르 카이트     3,600만 달러        NaN
# 1253                                          최건용           NaN        정해근
# 1254                                          NaN           NaN        NaN
#
#                                촬영 기간  \
# 0                                제작사
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 1250                             NaN
# 1251  2010년 6월 28일 ~ 2010년 12월 3일[3]
# 1252                             NaN
# 1253                             NaN
# 1254                             NaN
#
#                                                    출연            편집
# 0                                  시드니 스위니, 알바로 모르테 외      크리스챤 마시니
# 1     크리스틴 스튜어트케이티 오브라이언지나 말론안나 바리시니코프데이브 프랭코에드 해리스 外        마크 타운즈
# 2                                   차인표송윤아홍경인장혁양동근김민정            김현
# 3                                                 NaN           NaN
# 4                                                 NaN           NaN
# ...                                               ...           ...
# 1250                                              NaN        잭 스탠버그
# 1251                                              NaN  제프리 포드로버트 댈바
# 1252                                              NaN           NaN
# 1253                                       김윤진  박해일 외           조민석
# 1254                                              NaN           NaN
#
# [1255 rows x 24 columns]

# %%
import pandas as pd

# 파일 경로
file_path = '/content/fixed_movie_data'

# 파일 불러오기
try:
    df = pd.read_csv(file_path)
except pd.errors.ParserError:
    df = pd.read_excel(file_path)

# 'content' 열의 모든 값을 문자열로 변환
df['content'] = df['content'].astype(str)

# 'movie_id'와 'kind'로 그룹화하고, 중복 값을 결합하여 집계
df_aggregated = df.groupby(['movie_id', 'kind'])['content'].agg(lambda x: ' / '.join(x)).reset_index()

# 집계된 DataFrame을 피벗
pivot_df_aggregated = df_aggregated.pivot(index='movie_id', columns='kind', values='content').reset_index()

# 멀티레벨 열 이름 제거
pivot_df_aggregated.columns.name = None

# 원하는 열 순서
desired_columns = ['영화명', '장르', '감독', '각본', '제작', '원작', '출연', '촬영', '편집', '미술',
                   '음악', '음향', '촬영 기간', '수입사', '배급사', '개봉일', '상영 시간', '제작비',
                   '월드 박스오피스', '북미 박스오피스', '대한민국 총 관객 수', '상영 등급', '시놉시스']

# 열 순서 재정렬
pivot_df_reordered = pivot_df_aggregated[desired_columns]


pivot_df_reordered.head()
# Out:
#                      영화명                 장르         감독                   각본  \
# 0                 이매큘레이트            공포, 스릴러     마이클 모한               앤드류 로벨
# 1             러브 라이즈 블리딩         범죄, 멜로/로맨스  로즈 글래스[1]      로즈 글래스베로니카 토필스카
# 2                      짱  느와르, 드라마, 액션, 코미디        양윤호                  박계옥
# 3                  비포 선셋            드라마, 멜로  리처드 링클레이터  리처드 링클레이터에단 호크줄리 델피
# 4  명탐정 코난: 100만 달러의 펜타그램                NaN        NaN                  NaN
#
#                                             제작   원작  \
# 0  데이빗 버나드, 요나탄 다비노, 마이클 하임러, 테디 슈워츠먼, 시드니 스위니  nan
# 1                               안드레아 콘웰올리버 캐스먼  NaN
# 2                                 이혁기한성구최성식최성수  NaN
# 3                                     앤 워커-맥베이  NaN
# 4                                          NaN  NaN
#
#                                                 출연         촬영        편집   미술  \
# 0                               시드니 스위니, 알바로 모르테 외  엘리샤 크리스티안  크리스챤 마시니  nan
# 1  크리스틴 스튜어트케이티 오브라이언지나 말론안나 바리시니코프데이브 프랭코에드 해리스 外      벤 포즈먼    마크 타운즈  NaN
# 2                                차인표송윤아홍경인장혁양동근김민정        김윤수        김현  강승용
# 3                                              NaN      리 대니얼       NaN  NaN
# 4                                              NaN        NaN       NaN  NaN
#
#           음악   음향 촬영 기간         수입사                     배급사  \
# 0      윌 베이츠   의상   제작사      엔케이컨텐츠           Neon (주)디스테이션
# 1  클린트 맨셀[2]  NaN   NaN   스튜디오디에이치엘   A24 라이온스게이트 스튜디오디에이치엘
# 2  최만식 / 최만식  NaN   NaN         NaN             20세기 폭스 코리아
# 3        NaN  NaN   NaN     명보아트시네마    워너 인디펜던트 픽처스 THE 픽쳐스
# 4        NaN  NaN   NaN         NaN                     NaN
#
#                                             개봉일               상영 시간  제작비  \
# 0                  2024년 3월 22일 2024년 7월 17일[1]   89분 (1시간 28분 36초)   달러
# 1     2024년 3월 15일[3]  2024년 5월 3일 2024년 7월 10일  104분 (1시간 43분 48초)    -
# 2                                 1998년 11월 28일       90분 (1시간 47분)  NaN
# 3   2004년 7월 30일 2004년 10월 22일 2016년 8월 31일 재개봉                 80분  NaN
# 4                                           NaN                 NaN  NaN
#
#                         월드 박스오피스                      북미 박스오피스 대한민국 총 관객 수  \
# 0                              ?                             ?     15,361명
# 1  $11,826,868 (2024년 6월 22일 기준)  $8,335,797 (2024년 6월 22일 기준)         NaN
# 2                            NaN                           NaN         NaN
# 3                            NaN                           NaN         NaN
# 4                            NaN                           NaN         NaN
#
#           상영 등급                                               시놉시스
# 0    15세 이상 관람가  순수하고 신실한 믿음을 가진 수녀 '세실리아'(시드니 스위니).어느 비밀스러운 수녀...
# 1      청소년 관람불가  “멍청아, XX 사랑한다구!!”1989년, 체육관 매니저로 일상을 보내던 무기력한 ...
# 2    15세 이상 관람가  영생 고등학교 3학년 10반, 문제반으로 낙인 찍힌 이 반에 새로운 담임 황기풍(차...
# 3    15세 이상 관람가  비엔나에서의 꿈같은 하루, 6개월 후의 어긋난 약속…그리고 9년이 지난 오늘, 파리...
# 4           NaN  홋카이도의 하코다테에 있는 도검 재벌의 깊은 창고에 괴도 키드로부터의 예고장이 도착...

# %%
df.set_index('movie_id', inplace=True)

# %%
df.loc[1]
# Out:
#               kind                                            content
# movie_id
# 1              영화명                                         러브 라이즈 블리딩
# 1               장르                                         범죄, 멜로/로맨스
# 1               감독                                          로즈 글래스[1]
# 1               각본                                    로즈 글래스베로니카 토필스카
# 1               제작                                     안드레아 콘웰올리버 캐스먼
# 1               출연    크리스틴 스튜어트케이티 오브라이언지나 말론안나 바리시니코프데이브 프랭코에드 해리스 外
# 1               촬영                                              벤 포즈먼
# 1               편집                                             마크 타운즈
# 1               음악                                          클린트 맨셀[2]
# 1              수입사                                          스튜디오디에이치엘
# 1              배급사                              A24 라이온스게이트 스튜디오디에이치엘
# 1              개봉일          2024년 3월 15일[3]  2024년 5월 3일 2024년 7월 10일
# 1            상영 시간                                 104분 (1시간 43분 48초)
# 1              제작비                                                  -
# 1         북미 박스오피스                       $8,335,797 (2024년 6월 22일 기준)
# 1         월드 박스오피스                      $11,826,868 (2024년 6월 22일 기준)
# 1            상영 등급                                           청소년 관람불가
# 1             시놉시스  “멍청아, XX 사랑한다구!!”1989년, 체육관 매니저로 일상을 보내던 무기력한 ...

# %%
import pandas as pd

# 파일 경로
file_path = '/content/fixed_movie_data'

# 파일 불러오기
try:
    df = pd.read_csv(file_path)
except pd.errors.ParserError:
    df = pd.read_excel(file_path)

# 'content' 열의 모든 값을 문자열로 변환
df['content'] = df['content'].astype(str)

# %%
# 'movie_id'와 'kind'로 그룹화하고, 중복 값을 결합하여 집계
df_aggregated = df.groupby(['movie_id', 'kind'])['content'].agg(lambda x: ' / '.join(x)).reset_index()
df_aggregated
# Out:
#        movie_id         kind  \
# 0             0           각본
# 1             0           감독
# 2             0          개봉일
# 3             0  대한민국 총 관객 수
# 4             0           미술
# ...         ...          ...
# 16205      1253           촬영
# 16206      1253           출연
# 16207      1253           편집
# 16208      1254         시놉시스
# 16209      1254          영화명
#
#                                                  content
# 0                                                 앤드류 로벨
# 1                                                 마이클 모한
# 2                           2024년 3월 22일 2024년 7월 17일[1]
# 3                                                15,361명
# 4                                                    nan
# ...                                                  ...
# 16205                                                정해근
# 16206                                         김윤진  박해일 외
# 16207                                                조민석
# 16208  1941년, 진주만 공격의 거대한 음모가 밝혀진다1941년, 진주만 공격 60일 전...
# 16209                                                상하이
#
# [16210 rows x 3 columns]

# %%
# 집계된 DataFrame을 피벗
pivot_df_aggregated = df_aggregated.pivot(index='movie_id', columns='kind', values='content').reset_index()

# %%
pivot_df_aggregated.columns
# Out:
# Index(['movie_id', '각본', '감독', '개봉일', '대한민국 총 관객 수', '미술', '배급사', '북미 박스오피스',
#        '상영 등급', '상영 시간', '수입사', '시놉시스', '영화명', '원작', '월드 박스오피스', '음악', '음향',
#        '장르', '제작', '제작비', '촬영', '촬영 기간', '출연', '편집'],
#       dtype='object')

# %%
# 멀티레벨 열 이름 제거
pivot_df_aggregated.columns.name = None

# %%
pivot_df_aggregated.to_csv('fixed_movie_data2.csv', index=False)

# %%
pivot_df_aggregated
# Out:
#       movie_id                                                 각본         감독  \
# 0            0                                             앤드류 로벨     마이클 모한
# 1            1                                    로즈 글래스베로니카 토필스카  로즈 글래스[1]
# 2            2                                                박계옥        양윤호
# 3            3                                리처드 링클레이터에단 호크줄리 델피  리처드 링클레이터
# 4            4                                                NaN        NaN
# ...        ...                                                ...        ...
# 1250      1250                                                nan     앤드류 니콜
# 1251      1251                                크리스토퍼 마커스스티븐 맥필리[1]      조 존스턴
# 1252      1252  존 R. 스미스롭 스프래클링켈리 애즈베리마크 버턴앤디 라일리케빈 세실에밀리 쿡캐시 ...    켈리 애즈베리
# 1253      1253                                                NaN        NaN
# 1254      1254                                                NaN        NaN
#
#                                                개봉일       대한민국 총 관객 수  \
# 0                     2024년 3월 22일 2024년 7월 17일[1]           15,361명
# 1        2024년 3월 15일[3]  2024년 5월 3일 2024년 7월 10일               NaN
# 2                                    1998년 11월 28일               NaN
# 3      2004년 7월 30일 2004년 10월 22일 2016년 8월 31일 재개봉               NaN
# 4                                              NaN               NaN
# ...                                            ...               ...
# 1250                                           NaN               NaN
# 1251                     2011년 7월 22일 2011년 7월 28일     514,417명 (최종)
# 1252        2011년 2월 11일 2011년 2월 11일 2011년 4월 14일          221,195명
# 1253                                           NaN   1,006,947명 (최종)
# 1254                                           NaN               NaN
#
#                미술                       배급사                      북미 박스오피스  \
# 0             nan             Neon (주)디스테이션                             ?
# 1             NaN     A24 라이온스게이트 스튜디오디에이치엘  $8,335,797 (2024년 6월 22일 기준)
# 2             강승용               20세기 폭스 코리아                           NaN
# 3             NaN      워너 인디펜던트 픽처스 THE 픽쳐스                           NaN
# 4             NaN                       NaN                           NaN
# ...           ...                       ...                           ...
# 1250          NaN                       NaN                   $37,520,095
# 1251  숀 하워스릭 하인리히    파라마운트 픽처스 CJ ENM MOVIE             $176,654,505 (최종)
# 1252          NaN   월트 디즈니 스튜디오스 모션 픽처스 쇼박스                   $94,000,000
# 1253     김진철  전진원                                                     NaN
# 1254          NaN                       NaN                           NaN
#
#              상영 등급               상영 시간            수입사  \
# 0       15세 이상 관람가   89분 (1시간 28분 36초)         엔케이컨텐츠
# 1         청소년 관람불가  104분 (1시간 43분 48초)      스튜디오디에이치엘
# 2       15세 이상 관람가       90분 (1시간 47분)            NaN
# 3       15세 이상 관람가                 80분        명보아트시네마
# 4              NaN                 NaN            NaN
# ...            ...                 ...            ...
# 1250    12세 이상 관람가  109분 (1시간 49분 11초)            NaN
# 1251   12세 이상 관람가        124분 (2시간 4분)   CJ ENM MOVIE
# 1252        전체 관람가                 84분            NaN
# 1253           NaN                114분            NaN
# 1254           NaN                 NaN            NaN
#
#                                                    시놉시스  \
# 0     순수하고 신실한 믿음을 가진 수녀 '세실리아'(시드니 스위니).어느 비밀스러운 수녀...
# 1     “멍청아, XX 사랑한다구!!”1989년, 체육관 매니저로 일상을 보내던 무기력한 ...
# 2     영생 고등학교 3학년 10반, 문제반으로 낙인 찍힌 이 반에 새로운 담임 황기풍(차...
# 3     비엔나에서의 꿈같은 하루, 6개월 후의 어긋난 약속…그리고 9년이 지난 오늘, 파리...
# 4     홋카이도의 하코다테에 있는 도검 재벌의 깊은 창고에 괴도 키드로부터의 예고장이 도착...
# ...                                                 ...
# 1250  커피 1잔.. 4분, 권총 1정.. 3년, 스포츠카 1대.. 59년!모든 비용은 시...
# 1251  세계 전쟁으로 암흑에 빠진 시기, 한 남자가 군 입대를 자원한다. 그의 이름은 ‘스...
# 1252  링컨 대통령의 목숨을 앗아간 한 발의 총성! 암살에 공모한 8명 중 1명은 두 자녀...
# 1253  심장은 하나, 살려야 할 사람은 둘. 당신이라면 어떻게 하겠어?한 중년 여성이 뇌사...
# 1254  1941년, 진주만 공격의 거대한 음모가 밝혀진다1941년, 진주만 공격 60일 전...
#
#                         영화명                                   원작  \
# 0                    이매큘레이트                                  nan
# 1                러브 라이즈 블리딩                                  NaN
# 2                         짱                                  NaN
# 3                     비포 선셋                                  NaN
# 4     명탐정 코난: 100만 달러의 펜타그램                                  NaN
# ...                     ...                                  ...
# 1250                   인 타임                                  NaN
# 1251                퍼스트 어벤져  조 사이먼, 잭 커비 《캡틴 아메리카 코믹스 #1 (1940)》
# 1252               노미오와 줄리엣                윌리엄 셰익스피어, 《로미오와 줄리엣》
# 1253                 심장이 뛴다                                  NaN
# 1254                    상하이                                  NaN
#
#                            월드 박스오피스                             음악        음향  \
# 0                                 ?                          윌 베이츠        의상
# 1     $11,826,868 (2024년 6월 22일 기준)                      클린트 맨셀[2]       NaN
# 2                               NaN                      최만식 / 최만식       NaN
# 3                               NaN                            NaN       NaN
# 4                               NaN                            NaN       NaN
# ...                             ...                            ...       ...
# 1250                   $173,930,596                            NaN       NaN
# 1251              $370,569,774 (최종)                    앨런 실베스트리[2]       NaN
# 1252                   $193,967,670  엘튼 존버니 토핀크리스 P. 베이컨제임스 뉴튼 하워드       NaN
# 1253                            NaN                       방준석  복숭아  이승철  이성진
# 1254                            NaN                            NaN       NaN
#
#                                       장르  \
# 0                                공포, 스릴러
# 1                             범죄, 멜로/로맨스
# 2                      느와르, 드라마, 액션, 코미디
# 3                                드라마, 멜로
# 4                                    NaN
# ...                                  ...
# 1250                   SF, 사이버펑크, 액션, 범죄
# 1251  슈퍼히어로, 전쟁, SF, 액션, 어드벤처, 가상 역사 판타지
# 1252                애니메이션, 코미디, 판타지, 뮤지컬
# 1253                                 드라마
# 1254                                 NaN
#
#                                                제작           제작비         촬영  \
# 0     데이빗 버나드, 요나탄 다비노, 마이클 하임러, 테디 슈워츠먼, 시드니 스위니            달러  엘리샤 크리스티안
# 1                                  안드레아 콘웰올리버 캐스먼             -      벤 포즈먼
# 2                                    이혁기한성구최성식최성수           NaN        김윤수
# 3                                        앤 워커-맥베이           NaN      리 대니얼
# 4                                             NaN           NaN        NaN
# ...                                           ...           ...        ...
# 1250                                          NaN     4,000만 달러     로저 디킨스
# 1251                                       케빈 파이기  1억 4,000만 달러      셸리 존슨
# 1252                     데이비드 퍼니시스티브 해밀턴 쇼이고르 카이트     3,600만 달러        NaN
# 1253                                          최건용           NaN        정해근
# 1254                                          NaN           NaN        NaN
#
#                                촬영 기간  \
# 0                                제작사
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 1250                             NaN
# 1251  2010년 6월 28일 ~ 2010년 12월 3일[3]
# 1252                             NaN
# 1253                             NaN
# 1254                             NaN
#
#                                                    출연            편집
# 0                                  시드니 스위니, 알바로 모르테 외      크리스챤 마시니
# 1     크리스틴 스튜어트케이티 오브라이언지나 말론안나 바리시니코프데이브 프랭코에드 해리스 外        마크 타운즈
# 2                                   차인표송윤아홍경인장혁양동근김민정            김현
# 3                                                 NaN           NaN
# 4                                                 NaN           NaN
# ...                                               ...           ...
# 1250                                              NaN        잭 스탠버그
# 1251                                              NaN  제프리 포드로버트 댈바
# 1252                                              NaN           NaN
# 1253                                       김윤진  박해일 외           조민석
# 1254                                              NaN           NaN
#
# [1255 rows x 24 columns]

# %%
# 원하는 열 순서
desired_columns = ['영화명', '장르', '감독', '각본', '제작', '원작', '출연', '촬영', '편집', '미술',
                   '음악', '음향', '촬영 기간', '수입사', '배급사', '개봉일', '상영 시간', '제작비',
                   '월드 박스오피스', '북미 박스오피스', '대한민국 총 관객 수', '상영 등급', '시놉시스']

# 열 순서 재정렬
pivot_df_reordered = pivot_df_aggregated[desired_columns]


pivot_df_reordered.head()
# Out:
#                      영화명                 장르         감독                   각본  \
# 0                 이매큘레이트            공포, 스릴러     마이클 모한               앤드류 로벨
# 1             러브 라이즈 블리딩         범죄, 멜로/로맨스  로즈 글래스[1]      로즈 글래스베로니카 토필스카
# 2                      짱  느와르, 드라마, 액션, 코미디        양윤호                  박계옥
# 3                  비포 선셋            드라마, 멜로  리처드 링클레이터  리처드 링클레이터에단 호크줄리 델피
# 4  명탐정 코난: 100만 달러의 펜타그램                NaN        NaN                  NaN
#
#                                             제작   원작  \
# 0  데이빗 버나드, 요나탄 다비노, 마이클 하임러, 테디 슈워츠먼, 시드니 스위니  nan
# 1                               안드레아 콘웰올리버 캐스먼  NaN
# 2                                 이혁기한성구최성식최성수  NaN
# 3                                     앤 워커-맥베이  NaN
# 4                                          NaN  NaN
#
#                                                 출연         촬영        편집   미술  \
# 0                               시드니 스위니, 알바로 모르테 외  엘리샤 크리스티안  크리스챤 마시니  nan
# 1  크리스틴 스튜어트케이티 오브라이언지나 말론안나 바리시니코프데이브 프랭코에드 해리스 外      벤 포즈먼    마크 타운즈  NaN
# 2                                차인표송윤아홍경인장혁양동근김민정        김윤수        김현  강승용
# 3                                              NaN      리 대니얼       NaN  NaN
# 4                                              NaN        NaN       NaN  NaN
#
#           음악   음향 촬영 기간         수입사                     배급사  \
# 0      윌 베이츠   의상   제작사      엔케이컨텐츠           Neon (주)디스테이션
# 1  클린트 맨셀[2]  NaN   NaN   스튜디오디에이치엘   A24 라이온스게이트 스튜디오디에이치엘
# 2  최만식 / 최만식  NaN   NaN         NaN             20세기 폭스 코리아
# 3        NaN  NaN   NaN     명보아트시네마    워너 인디펜던트 픽처스 THE 픽쳐스
# 4        NaN  NaN   NaN         NaN                     NaN
#
#                                             개봉일               상영 시간  제작비  \
# 0                  2024년 3월 22일 2024년 7월 17일[1]   89분 (1시간 28분 36초)   달러
# 1     2024년 3월 15일[3]  2024년 5월 3일 2024년 7월 10일  104분 (1시간 43분 48초)    -
# 2                                 1998년 11월 28일       90분 (1시간 47분)  NaN
# 3   2004년 7월 30일 2004년 10월 22일 2016년 8월 31일 재개봉                 80분  NaN
# 4                                           NaN                 NaN  NaN
#
#                         월드 박스오피스                      북미 박스오피스 대한민국 총 관객 수  \
# 0                              ?                             ?     15,361명
# 1  $11,826,868 (2024년 6월 22일 기준)  $8,335,797 (2024년 6월 22일 기준)         NaN
# 2                            NaN                           NaN         NaN
# 3                            NaN                           NaN         NaN
# 4                            NaN                           NaN         NaN
#
#           상영 등급                                               시놉시스
# 0    15세 이상 관람가  순수하고 신실한 믿음을 가진 수녀 '세실리아'(시드니 스위니).어느 비밀스러운 수녀...
# 1      청소년 관람불가  “멍청아, XX 사랑한다구!!”1989년, 체육관 매니저로 일상을 보내던 무기력한 ...
# 2    15세 이상 관람가  영생 고등학교 3학년 10반, 문제반으로 낙인 찍힌 이 반에 새로운 담임 황기풍(차...
# 3    15세 이상 관람가  비엔나에서의 꿈같은 하루, 6개월 후의 어긋난 약속…그리고 9년이 지난 오늘, 파리...
# 4           NaN  홋카이도의 하코다테에 있는 도검 재벌의 깊은 창고에 괴도 키드로부터의 예고장이 도착...

# %%
pivot_df_reordered
# Out:
#                         영화명                                  장르         감독  \
# 0                    이매큘레이트                             공포, 스릴러     마이클 모한
# 1                러브 라이즈 블리딩                          범죄, 멜로/로맨스  로즈 글래스[1]
# 2                         짱                   느와르, 드라마, 액션, 코미디        양윤호
# 3                     비포 선셋                             드라마, 멜로  리처드 링클레이터
# 4     명탐정 코난: 100만 달러의 펜타그램                                 NaN        NaN
# ...                     ...                                 ...        ...
# 1250                   인 타임                   SF, 사이버펑크, 액션, 범죄     앤드류 니콜
# 1251                퍼스트 어벤져  슈퍼히어로, 전쟁, SF, 액션, 어드벤처, 가상 역사 판타지      조 존스턴
# 1252               노미오와 줄리엣                애니메이션, 코미디, 판타지, 뮤지컬    켈리 애즈베리
# 1253                 심장이 뛴다                                 드라마        NaN
# 1254                    상하이                                 NaN        NaN
#
#                                                      각본  \
# 0                                                앤드류 로벨
# 1                                       로즈 글래스베로니카 토필스카
# 2                                                   박계옥
# 3                                   리처드 링클레이터에단 호크줄리 델피
# 4                                                   NaN
# ...                                                 ...
# 1250                                                nan
# 1251                                크리스토퍼 마커스스티븐 맥필리[1]
# 1252  존 R. 스미스롭 스프래클링켈리 애즈베리마크 버턴앤디 라일리케빈 세실에밀리 쿡캐시 ...
# 1253                                                NaN
# 1254                                                NaN
#
#                                                제작  \
# 0     데이빗 버나드, 요나탄 다비노, 마이클 하임러, 테디 슈워츠먼, 시드니 스위니
# 1                                  안드레아 콘웰올리버 캐스먼
# 2                                    이혁기한성구최성식최성수
# 3                                        앤 워커-맥베이
# 4                                             NaN
# ...                                           ...
# 1250                                          NaN
# 1251                                       케빈 파이기
# 1252                     데이비드 퍼니시스티브 해밀턴 쇼이고르 카이트
# 1253                                          최건용
# 1254                                          NaN
#
#                                        원작  \
# 0                                     nan
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 1250                                  NaN
# 1251  조 사이먼, 잭 커비 《캡틴 아메리카 코믹스 #1 (1940)》
# 1252                윌리엄 셰익스피어, 《로미오와 줄리엣》
# 1253                                  NaN
# 1254                                  NaN
#
#                                                    출연         촬영  \
# 0                                  시드니 스위니, 알바로 모르테 외  엘리샤 크리스티안
# 1     크리스틴 스튜어트케이티 오브라이언지나 말론안나 바리시니코프데이브 프랭코에드 해리스 外      벤 포즈먼
# 2                                   차인표송윤아홍경인장혁양동근김민정        김윤수
# 3                                                 NaN      리 대니얼
# 4                                                 NaN        NaN
# ...                                               ...        ...
# 1250                                              NaN     로저 디킨스
# 1251                                              NaN      셸리 존슨
# 1252                                              NaN        NaN
# 1253                                       김윤진  박해일 외        정해근
# 1254                                              NaN        NaN
#
#                 편집           미술                             음악        음향  \
# 0         크리스챤 마시니          nan                          윌 베이츠        의상
# 1           마크 타운즈          NaN                      클린트 맨셀[2]       NaN
# 2               김현          강승용                      최만식 / 최만식       NaN
# 3              NaN          NaN                            NaN       NaN
# 4              NaN          NaN                            NaN       NaN
# ...            ...          ...                            ...       ...
# 1250        잭 스탠버그          NaN                            NaN       NaN
# 1251  제프리 포드로버트 댈바  숀 하워스릭 하인리히                    앨런 실베스트리[2]       NaN
# 1252           NaN          NaN  엘튼 존버니 토핀크리스 P. 베이컨제임스 뉴튼 하워드       NaN
# 1253           조민석     김진철  전진원                       방준석  복숭아  이승철  이성진
# 1254           NaN          NaN                            NaN       NaN
#
#                                촬영 기간            수입사                       배급사  \
# 0                                제작사         엔케이컨텐츠             Neon (주)디스테이션
# 1                                NaN      스튜디오디에이치엘     A24 라이온스게이트 스튜디오디에이치엘
# 2                                NaN            NaN               20세기 폭스 코리아
# 3                                NaN        명보아트시네마      워너 인디펜던트 픽처스 THE 픽쳐스
# 4                                NaN            NaN                       NaN
# ...                              ...            ...                       ...
# 1250                             NaN            NaN                       NaN
# 1251  2010년 6월 28일 ~ 2010년 12월 3일[3]   CJ ENM MOVIE    파라마운트 픽처스 CJ ENM MOVIE
# 1252                             NaN            NaN   월트 디즈니 스튜디오스 모션 픽처스 쇼박스
# 1253                             NaN            NaN
# 1254                             NaN            NaN                       NaN
#
#                                                개봉일               상영 시간  \
# 0                     2024년 3월 22일 2024년 7월 17일[1]   89분 (1시간 28분 36초)
# 1        2024년 3월 15일[3]  2024년 5월 3일 2024년 7월 10일  104분 (1시간 43분 48초)
# 2                                    1998년 11월 28일       90분 (1시간 47분)
# 3      2004년 7월 30일 2004년 10월 22일 2016년 8월 31일 재개봉                 80분
# 4                                              NaN                 NaN
# ...                                            ...                 ...
# 1250                                           NaN  109분 (1시간 49분 11초)
# 1251                     2011년 7월 22일 2011년 7월 28일       124분 (2시간 4분)
# 1252        2011년 2월 11일 2011년 2월 11일 2011년 4월 14일                 84분
# 1253                                           NaN                114분
# 1254                                           NaN                 NaN
#
#                제작비                       월드 박스오피스  \
# 0               달러                              ?
# 1                -  $11,826,868 (2024년 6월 22일 기준)
# 2              NaN                            NaN
# 3              NaN                            NaN
# 4              NaN                            NaN
# ...            ...                            ...
# 1250     4,000만 달러                   $173,930,596
# 1251  1억 4,000만 달러              $370,569,774 (최종)
# 1252     3,600만 달러                   $193,967,670
# 1253           NaN                            NaN
# 1254           NaN                            NaN
#
#                           북미 박스오피스       대한민국 총 관객 수         상영 등급  \
# 0                                ?           15,361명    15세 이상 관람가
# 1     $8,335,797 (2024년 6월 22일 기준)               NaN      청소년 관람불가
# 2                              NaN               NaN    15세 이상 관람가
# 3                              NaN               NaN    15세 이상 관람가
# 4                              NaN               NaN           NaN
# ...                            ...               ...           ...
# 1250                   $37,520,095               NaN    12세 이상 관람가
# 1251             $176,654,505 (최종)     514,417명 (최종)   12세 이상 관람가
# 1252                   $94,000,000          221,195명        전체 관람가
# 1253                           NaN   1,006,947명 (최종)           NaN
# 1254                           NaN               NaN           NaN
#
#                                                    시놉시스
# 0     순수하고 신실한 믿음을 가진 수녀 '세실리아'(시드니 스위니).어느 비밀스러운 수녀...
# 1     “멍청아, XX 사랑한다구!!”1989년, 체육관 매니저로 일상을 보내던 무기력한 ...
# 2     영생 고등학교 3학년 10반, 문제반으로 낙인 찍힌 이 반에 새로운 담임 황기풍(차...
# 3     비엔나에서의 꿈같은 하루, 6개월 후의 어긋난 약속…그리고 9년이 지난 오늘, 파리...
# 4     홋카이도의 하코다테에 있는 도검 재벌의 깊은 창고에 괴도 키드로부터의 예고장이 도착...
# ...                                                 ...
# 1250  커피 1잔.. 4분, 권총 1정.. 3년, 스포츠카 1대.. 59년!모든 비용은 시...
# 1251  세계 전쟁으로 암흑에 빠진 시기, 한 남자가 군 입대를 자원한다. 그의 이름은 ‘스...
# 1252  링컨 대통령의 목숨을 앗아간 한 발의 총성! 암살에 공모한 8명 중 1명은 두 자녀...
# 1253  심장은 하나, 살려야 할 사람은 둘. 당신이라면 어떻게 하겠어?한 중년 여성이 뇌사...
# 1254  1941년, 진주만 공격의 거대한 음모가 밝혀진다1941년, 진주만 공격 60일 전...
#
# [1255 rows x 23 columns]

# %%
pivot_df_reordered.to_csv('fixed_movie_data2.csv', index=False)

# %%
duplicate_entries = df[df.duplicated(subset=['movie_id', 'kind'], keep=False)]



duplicate_entries.sort_values(by=['movie_id', 'kind']).head(20)
# Out:
#        movie_id      kind      content
# 50            2        음악          최만식
# 51            2        음악          최만식
# 4081        283        미술      누노베 마사토
# 4084        283        미술     누노베 마사토
# 4840        339        음향          공태원
# 4841        339        음향          박규리
# 6952        481  월드 박스오피스  $17,887,384
# 6953        481  월드 박스오피스            -
# 10032       727        각본     다니엘 스티플만
# 10034       727        각본     다니엘 스티플먼

# %%
df=pivot_df_reordered

# %%
df.to_csv('fixed_movie_data1.csv', index=False)

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
categorical_columns = list(df.columns)

# %%
encoders = {col: LabelEncoder() for col in categorical_columns}
encoders
# Out:
# {'영화명': LabelEncoder(),
#  '장르': LabelEncoder(),
#  '감독': LabelEncoder(),
#  '각본': LabelEncoder(),
#  '제작': LabelEncoder(),
#  '원작': LabelEncoder(),
#  '출연': LabelEncoder(),
#  '촬영': LabelEncoder(),
#  '편집': LabelEncoder(),
#  '미술': LabelEncoder(),
#  '음악': LabelEncoder(),
#  '음향': LabelEncoder(),
#  '촬영 기간': LabelEncoder(),
#  '수입사': LabelEncoder(),
#  '배급사': LabelEncoder(),
#  '개봉일': LabelEncoder(),
#  '상영 시간': LabelEncoder(),
#  '제작비': LabelEncoder(),
#  '월드 박스오피스': LabelEncoder(),
#  '북미 박스오피스': LabelEncoder(),
#  '대한민국 총 관객 수': LabelEncoder(),
#  '상영 등급': LabelEncoder(),
#  '시놉시스': LabelEncoder()}

# %%
for col in categorical_columns:
    df[col] = encoders[col].fit_transform(df[col])

# %%
#  7대3 으로 train과 test로 나눔
train_df, test_df = train_test_split(df, test_size=0.3, random_state=42)

# train과 test에서 target과 feature
X_train = train_df.drop(columns=['영화명'])
y_train = train_df['영화명']

X_test = test_df.drop(columns=['영화명'])
y_test = test_df['영화명']

# %%
X_train
# Out:
#        장르   감독   각본   제작   원작   출연   촬영   편집   미술   음악  음향  촬영 기간  수입사  배급사  \
# 905    82  776  724  689  275  574  544  446  302  513  64    214  216  125
# 714   291   29   24  464  262  168  220   29   22  189  12    214  216  243
# 66     82  758    6  689  275  574  544    3  302   64  64    214  216  371
# 67    454  233  635   24  268  574  544  446  302  513  64    211  216  575
# 413    57  776  724  689  275  574  544  446  302  513  64    214  216  323
# ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ..    ...  ...  ...
# 1044  406  371  335  128   80  500  544  446  302   70  64    214  216  498
# 1095  314  518  248  475  275  124  171   68  302  342  64    214  216  393
# 1130  694  776  724  689  275  574  544  446  302  513  64    214  216  575
# 860   694  776  724  689  275  574  544  446  302  513  64    214  216  575
# 1126  694  776  724  689  275  574  544  446  302  513  64    214  216  575
#
#       개봉일  상영 시간  제작비  월드 박스오피스  북미 박스오피스  대한민국 총 관객 수  상영 등급  시놉시스
# 905   274     13  339       169        82          559     75    83
# 714   428    212   69       142       428          559     75   934
# 66    725    333  385       516       428          492     39   767
# 67    780    331  385       606       428           96     38   280
# 413   542    321  385       617       428          559     48   979
# ...   ...    ...  ...       ...       ...          ...    ...   ...
# 1044  210    182  251        98       362          370     26   677
# 1095  218     93  251       523       199          559     75   135
# 1130  780    379  385       617       428          559     75   313
# 860   780    379  385       617       428          559     75    57
# 1126  780    379  385       617       428          559     75    68
#
# [878 rows x 22 columns]

# %%
y_test
# Out:
# 1196     530
# 101     1090
# 51        21
# 63        45
# 1070     508
#         ...
# 1114     648
# 1079     517
# 227     1051
# 1125    1011
# 573       32
# Name: 영화명, Length: 377, dtype: int64

# %%
# !pip install konlpy
# !pip install pandas openpyxl xlrd konlpy scikit-learn
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.10/dist-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.5.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.4)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (24.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.5)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.10/dist-packages (2.0.1)
# Requirement already satisfied: konlpy in /usr/local/lib/python3.10/dist-packages (0.6.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.5.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (24.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from konlpy.tag import Okt

# %%
data=pd.read_csv('/content/fixed_movie_data2.csv')

# %%
data.columns
data
# Out:
#                         영화명                                  장르         감독  \
# 0                    이매큘레이트                             공포, 스릴러     마이클 모한
# 1                러브 라이즈 블리딩                          범죄, 멜로/로맨스  로즈 글래스[1]
# 2                         짱                   느와르, 드라마, 액션, 코미디        양윤호
# 3                     비포 선셋                             드라마, 멜로  리처드 링클레이터
# 4     명탐정 코난: 100만 달러의 펜타그램                                 NaN        NaN
# ...                     ...                                 ...        ...
# 1250                   인 타임                   SF, 사이버펑크, 액션, 범죄     앤드류 니콜
# 1251                퍼스트 어벤져  슈퍼히어로, 전쟁, SF, 액션, 어드벤처, 가상 역사 판타지      조 존스턴
# 1252               노미오와 줄리엣                애니메이션, 코미디, 판타지, 뮤지컬    켈리 애즈베리
# 1253                 심장이 뛴다                                 드라마        NaN
# 1254                    상하이                                 NaN        NaN
#
#                                                      각본  \
# 0                                                앤드류 로벨
# 1                                       로즈 글래스베로니카 토필스카
# 2                                                   박계옥
# 3                                   리처드 링클레이터에단 호크줄리 델피
# 4                                                   NaN
# ...                                                 ...
# 1250                                                NaN
# 1251                                크리스토퍼 마커스스티븐 맥필리[1]
# 1252  존 R. 스미스롭 스프래클링켈리 애즈베리마크 버턴앤디 라일리케빈 세실에밀리 쿡캐시 ...
# 1253                                                NaN
# 1254                                                NaN
#
#                                                제작  \
# 0     데이빗 버나드, 요나탄 다비노, 마이클 하임러, 테디 슈워츠먼, 시드니 스위니
# 1                                  안드레아 콘웰올리버 캐스먼
# 2                                    이혁기한성구최성식최성수
# 3                                        앤 워커-맥베이
# 4                                             NaN
# ...                                           ...
# 1250                                          NaN
# 1251                                       케빈 파이기
# 1252                     데이비드 퍼니시스티브 해밀턴 쇼이고르 카이트
# 1253                                          최건용
# 1254                                          NaN
#
#                                        원작  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 1250                                  NaN
# 1251  조 사이먼, 잭 커비 《캡틴 아메리카 코믹스 #1 (1940)》
# 1252                윌리엄 셰익스피어, 《로미오와 줄리엣》
# 1253                                  NaN
# 1254                                  NaN
#
#                                                    출연         촬영  \
# 0                                  시드니 스위니, 알바로 모르테 외  엘리샤 크리스티안
# 1     크리스틴 스튜어트케이티 오브라이언지나 말론안나 바리시니코프데이브 프랭코에드 해리스 外      벤 포즈먼
# 2                                   차인표송윤아홍경인장혁양동근김민정        김윤수
# 3                                                 NaN      리 대니얼
# 4                                                 NaN        NaN
# ...                                               ...        ...
# 1250                                              NaN     로저 디킨스
# 1251                                              NaN      셸리 존슨
# 1252                                              NaN        NaN
# 1253                                       김윤진  박해일 외        정해근
# 1254                                              NaN        NaN
#
#                 편집           미술                             음악        음향  \
# 0         크리스챤 마시니          NaN                          윌 베이츠        의상
# 1           마크 타운즈          NaN                      클린트 맨셀[2]       NaN
# 2               김현          강승용                      최만식 / 최만식       NaN
# 3              NaN          NaN                            NaN       NaN
# 4              NaN          NaN                            NaN       NaN
# ...            ...          ...                            ...       ...
# 1250        잭 스탠버그          NaN                            NaN       NaN
# 1251  제프리 포드로버트 댈바  숀 하워스릭 하인리히                    앨런 실베스트리[2]       NaN
# 1252           NaN          NaN  엘튼 존버니 토핀크리스 P. 베이컨제임스 뉴튼 하워드       NaN
# 1253           조민석     김진철  전진원                       방준석  복숭아  이승철  이성진
# 1254           NaN          NaN                            NaN       NaN
#
#                                촬영 기간            수입사                       배급사  \
# 0                                제작사         엔케이컨텐츠             Neon (주)디스테이션
# 1                                NaN      스튜디오디에이치엘     A24 라이온스게이트 스튜디오디에이치엘
# 2                                NaN            NaN               20세기 폭스 코리아
# 3                                NaN        명보아트시네마      워너 인디펜던트 픽처스 THE 픽쳐스
# 4                                NaN            NaN                       NaN
# ...                              ...            ...                       ...
# 1250                             NaN            NaN                       NaN
# 1251  2010년 6월 28일 ~ 2010년 12월 3일[3]   CJ ENM MOVIE    파라마운트 픽처스 CJ ENM MOVIE
# 1252                             NaN            NaN   월트 디즈니 스튜디오스 모션 픽처스 쇼박스
# 1253                             NaN            NaN
# 1254                             NaN            NaN                       NaN
#
#                                                개봉일               상영 시간  \
# 0                     2024년 3월 22일 2024년 7월 17일[1]   89분 (1시간 28분 36초)
# 1        2024년 3월 15일[3]  2024년 5월 3일 2024년 7월 10일  104분 (1시간 43분 48초)
# 2                                    1998년 11월 28일       90분 (1시간 47분)
# 3      2004년 7월 30일 2004년 10월 22일 2016년 8월 31일 재개봉                 80분
# 4                                              NaN                 NaN
# ...                                            ...                 ...
# 1250                                           NaN  109분 (1시간 49분 11초)
# 1251                     2011년 7월 22일 2011년 7월 28일       124분 (2시간 4분)
# 1252        2011년 2월 11일 2011년 2월 11일 2011년 4월 14일                 84분
# 1253                                           NaN                114분
# 1254                                           NaN                 NaN
#
#                제작비                       월드 박스오피스  \
# 0               달러                              ?
# 1                -  $11,826,868 (2024년 6월 22일 기준)
# 2              NaN                            NaN
# 3              NaN                            NaN
# 4              NaN                            NaN
# ...            ...                            ...
# 1250     4,000만 달러                   $173,930,596
# 1251  1억 4,000만 달러              $370,569,774 (최종)
# 1252     3,600만 달러                   $193,967,670
# 1253           NaN                            NaN
# 1254           NaN                            NaN
#
#                           북미 박스오피스       대한민국 총 관객 수         상영 등급  \
# 0                                ?           15,361명    15세 이상 관람가
# 1     $8,335,797 (2024년 6월 22일 기준)               NaN      청소년 관람불가
# 2                              NaN               NaN    15세 이상 관람가
# 3                              NaN               NaN    15세 이상 관람가
# 4                              NaN               NaN           NaN
# ...                            ...               ...           ...
# 1250                   $37,520,095               NaN    12세 이상 관람가
# 1251             $176,654,505 (최종)     514,417명 (최종)   12세 이상 관람가
# 1252                   $94,000,000          221,195명        전체 관람가
# 1253                           NaN   1,006,947명 (최종)           NaN
# 1254                           NaN               NaN           NaN
#
#                                                    시놉시스
# 0     순수하고 신실한 믿음을 가진 수녀 '세실리아'(시드니 스위니).어느 비밀스러운 수녀...
# 1     “멍청아, XX 사랑한다구!!”1989년, 체육관 매니저로 일상을 보내던 무기력한 ...
# 2     영생 고등학교 3학년 10반, 문제반으로 낙인 찍힌 이 반에 새로운 담임 황기풍(차...
# 3     비엔나에서의 꿈같은 하루, 6개월 후의 어긋난 약속…그리고 9년이 지난 오늘, 파리...
# 4     홋카이도의 하코다테에 있는 도검 재벌의 깊은 창고에 괴도 키드로부터의 예고장이 도착...
# ...                                                 ...
# 1250  커피 1잔.. 4분, 권총 1정.. 3년, 스포츠카 1대.. 59년!모든 비용은 시...
# 1251  세계 전쟁으로 암흑에 빠진 시기, 한 남자가 군 입대를 자원한다. 그의 이름은 ‘스...
# 1252  링컨 대통령의 목숨을 앗아간 한 발의 총성! 암살에 공모한 8명 중 1명은 두 자녀...
# 1253  심장은 하나, 살려야 할 사람은 둘. 당신이라면 어떻게 하겠어?한 중년 여성이 뇌사...
# 1254  1941년, 진주만 공격의 거대한 음모가 밝혀진다1941년, 진주만 공격 60일 전...
#
# [1255 rows x 23 columns]

# %%
data.fillna('', inplace=True)

# %%
# NLP를 위한 텍스트 특성 결합
# Adjusted column names to match the new names
data['Text'] = (data['영화명'] + ' ' + data['장르'] + ' ' + data['감독'] + ' ' + data['각본'] + ' ' + data['제작']  + ' ' + data['원작'] + ' ' + data['출연']+ ' ' + data['촬영'] + ' ' + data['편집'] + ' ' + data['미술'] + ' ' + data['음악'] + ' ' + data['음향'] + ' ' + data['촬영 기간'] + ' ' + data['수입사'] + ' ' + data['배급사'] + ' ' + data['개봉일'] + ' ' + data['상영 시간'] + ' ' + data['제작비']+ ' ' + data['월드 박스오피스']+ ' ' + data['북미 박스오피스']+ ' ' + data['대한민국 총 관객 수']+ ' ' + data['상영 등급']+ ' ' + data['시놉시스'])

# %%
# 한국어 텍스트 처리를 위한 Okt 초기화
okt = Okt()

# %%
# 텍스트를 토큰화하고 원형으로 복원하는 함수 정의
def tokenize_and_lemmatize(text):
    if isinstance(text, str):  # Check if 'text' is a string
        tokens = okt.morphs(text, stem=True)
        return ' '.join(tokens)
    else:
        return ''  # Return an empty string or handle NaN case appropriately

# %%
# 텍스트 데이터에 함수 적용
data['Processed_Text'] = data['Text'].apply(tokenize_and_lemmatize)

# %%
# 처리된 텍스트 데이터 벡터화
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(data['Processed_Text'])

# %%
# 코사인 유사도 행렬 계산
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
# Out:
# array([[1.        , 0.05898628, 0.01506177, ..., 0.00942825, 0.01124184,
#         0.01044136],
#        [0.05898628, 1.        , 0.00512545, ..., 0.0050843 , 0.00258688,
#         0.00239732],
#        [0.01506177, 0.00512545, 1.        , ..., 0.0077057 , 0.02372745,
#         0.01156283],
#        ...,
#        [0.00942825, 0.0050843 , 0.0077057 , ..., 1.        , 0.00441403,
#         0.01027357],
#        [0.01124184, 0.00258688, 0.02372745, ..., 0.00441403, 1.        ,
#         0.0228757 ],
#        [0.01044136, 0.00239732, 0.01156283, ..., 0.01027357, 0.0228757 ,
#         1.        ]])

# %%
def get_recommendations(title, cosine_sim=cosine_sim):
    if title not in data['영화명'].values:
        return f"영화명 '{title}'을(를) 데이터셋에서 찾을 수 없습니다."

    idx = data[data['영화명'] == title].index
    if len(idx) == 0:
        return f"영화명 '{title}'을(를) 데이터셋에서 찾을 수 없습니다."

    idx = idx[0]  # Take the first index if multiple entries are found (though unlikely)

    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]  # 상위 10개
    movie_indices = [i[0] for i in sim_scores]
    return data['영화명'].iloc[movie_indices].tolist()

# %%
# 예시 사용법
movie_title = '범죄도시'  # 관심 있는 영화명으로 교체
recommended_movies = get_recommendations(movie_title)
print(f"'{movie_title}'와(과) 유사한 영화:\n", recommended_movies)
# Out:
# '범죄도시'와(과) 유사한 영화:
#  ['범죄도시', '나쁜 녀석들: 더 무비', '범죄와의 전쟁: 나쁜놈들 전성시대', '작전', '나쁜 녀석들: 포에버', '시카리오: 암살자의 도시', '독전', '무뢰한', '맨 온 엣지', '공조']

# %%
def get_recommendations_by_genre(title, genre, cosine_sim=cosine_sim):
    recommendations = get_recommendations(title, cosine_sim)
    if isinstance(recommendations, str):
        return recommendations

    filtered_recommendations = []
    for movie in recommendations:
        movie_genre = data[data['영화명'] == movie]['장르'].values
        if len(movie_genre) > 0 and genre in movie_genre[0]:
            filtered_recommendations.append(movie)

    if not filtered_recommendations:
        return f"'{title}'와(과) 유사한 영화 중 '{genre}' 장르를 포함한 영화를 찾을 수 없습니다."

    return filtered_recommendations

# 예시 사용법
movie_title = '범죄도시'  # 관심 있는 영화명으로 교체
genre = '범죄'
recommended_movies = get_recommendations_by_genre(movie_title, genre)
print(f"'{movie_title}'와(과) 유사하고 '{genre}' 장르가 포함된 영화:\n", recommended_movies)
# Out:
# '범죄도시'와(과) 유사하고 '범죄' 장르가 포함된 영화:
#  ['범죄도시', '범죄와의 전쟁: 나쁜놈들 전성시대', '작전', '나쁜 녀석들: 포에버', '독전', '무뢰한', '공조']

# %%
def get_recommendations(title=None, genre=None, director=None, year=None, cosine_sim=cosine_sim):
    if title:
        if title not in data['영화명'].values:
            return f"영화명 '{title}'을(를) 데이터셋에서 찾을 수 없습니다."
        idx = data[data['영화명'] == title].index
        if len(idx) == 0:
            return f"영화명 '{title}'을(를) 데이터셋에서 찾을 수 없습니다."
        idx = idx[0]  # Take the first index if multiple entries are found (though unlikely)
        sim_scores = list(enumerate(cosine_sim[idx]))
        sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
        sim_scores = sim_scores[1:11]  # 상위 10개 추천
        movie_indices = [i[0] for i in sim_scores]
        recommendations = data.iloc[movie_indices]
    else:
        conditions = []
        if genre:
            conditions.append(data['장르'].str.contains(genre, na=False))
        if director:
            conditions.append(data['감독'].str.contains(director, na=False))
            print(conditions)
        if year:
            conditions.append(data['개봉일'].astype(str).str.contains(year, na=False))
        if not conditions:
            return "영화명, 장르, 감독 또는 제작 연도 중 하나를 입력하세요."
        recommendations = data
        for condition in conditions:
            recommendations = recommendations[condition]
        recommendations = recommendations.head(10)

    recommendations = recommendations.copy()
    # recommendations.loc[:, '개봉일'] = recommendations['개봉일'].astype(int)
    return recommendations[['영화명', '장르', '감독', '개봉일']].values.tolist()

# 사용자 입력을 통한 영화명, 장르, 감독, 제작 연도 입력
movie_title = input("추천을 받고 싶은 영화명을 입력하세요 (생략 가능): ").strip()
genre = input("추천을 받고 싶은 장르를 입력하세요 (생략 가능): ").strip()
director = input("추천을 받고 싶은 감독을 입력하세요 (생략 가능): ").strip()
year = input("추천을 받고 싶은 제작 연도를 입력하세요 (생략 가능): ").strip()

# 빈 문자열을 None으로 변환
movie_title = movie_title if movie_title else None
genre = genre if genre else None
director = director if director else None
year = year if year else None

recommended_movies = get_recommendations(movie_title, genre, director, year)
print("추천된 영화들:\n", recommended_movies)
# Out:
# 추천을 받고 싶은 영화 제목을 입력하세요 (생략 가능):
# 추천을 받고 싶은 장르를 입력하세요 (생략 가능):
# 추천을 받고 싶은 감독을 입력하세요 (생략 가능): 강윤성
# 추천을 받고 싶은 제작 연도를 입력하세요 (생략 가능):
# [0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1250    False
# 1251    False
# 1252    False
# 1253    False
# 1254    False
# Name: 감독, Length: 1255, dtype: bool]
# 추천된 영화들:
#  [['범죄도시', '범죄, 액션, 스릴러, 느와르, 블랙 코미디, 형사', '강윤성', ''], ['범죄도시', '범죄, 액션, 스릴러, 느와르, 블랙 코미디, 형사', '강윤성', '']]

# %%
data[data['영화명']=='범죄도시']
# Out:
#        영화명                            장르   감독  각본 제작 원작 출연   촬영   편집   미술 음악  \
# 355   범죄도시  범죄, 액션, 스릴러, 느와르, 블랙 코미디, 형사  강윤성  기획           주성림  김선민  김성규
# 1109  범죄도시  범죄, 액션, 스릴러, 느와르, 블랙 코미디, 형사  강윤성  기획           주성림  김선민  김성규
#
#      음향 촬영 기간 수입사 배급사 개봉일          상영 시간    제작비          월드 박스오피스 북미 박스오피스  \
# 355                        121분 (2시간 1분)  70억 원  $52,097,753 (최종)
# 1109                       121분 (2시간 1분)  70억 원  $52,097,753 (최종)
#
#           대한민국 총 관객 수       상영 등급  \
# 355   6,880,546명 (최종)    청소년 관람불가
# 1109  6,880,546명 (최종)    청소년 관람불가
#
#                                                    시놉시스  \
# 355   오늘 밤, 다 쓸어버린다!2004년 서울…하얼빈에서 넘어와 단숨에 기존 조직들을 장...
# 1109  오늘 밤, 다 쓸어버린다!2004년 서울…하얼빈에서 넘어와 단숨에 기존 조직들을 장...
#
#                                                    Text  \
# 355   범죄도시 범죄, 액션, 스릴러, 느와르, 블랙 코미디, 형사 강윤성 기획    주성...
# 1109  범죄도시 범죄, 액션, 스릴러, 느와르, 블랙 코미디, 형사 강윤성 기획    주성...
#
#                                          Processed_Text
# 355   범죄 도시 범죄 , 액션 , 스릴러 , 느와르 , 블랙 코미디 , 형사 강윤성 기획...
# 1109  범죄 도시 범죄 , 액션 , 스릴러 , 느와르 , 블랙 코미디 , 형사 강윤성 기획...

# %%
import matplotlib
from matplotlib import font_manager, rc
import platform
import warnings

# 한글 폰트 다운로드 및 설치
# !apt-get update -qq
# !apt-get install -qq fonts-nanum

# 한글 폰트를 matplotlib에 설정
import matplotlib.font_manager as fm

font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
font = fm.FontProperties(fname=font_path, size=10)
matplotlib.rc('font', family=font.get_name())
matplotlib.rcParams['axes.unicode_minus'] = False

# 경고 무시
warnings.filterwarnings("ignore")
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import euclidean_distances
from konlpy.tag import Okt
import matplotlib.pyplot as plt
# 유클리드 거리 행렬 계산
euclidean_dist = euclidean_distances(tfidf_matrix, tfidf_matrix)

def get_recommendations(movie_title=None, genre=None, director=None, year=None, euclidean_dist=euclidean_dist):
    if not movie_title and not genre and not director and not year:
        return "영화명, 장르, 감독 또는 제작 연도 중 하나를 입력하세요."

    filtered_data = data.copy()

    # 입력된 조건을 모두 만족하는 영화 필터링
    if genre:
        filtered_data = filtered_data[filtered_data['장르'].str.contains(genre, na=False)]
    if director:
        filtered_data = filtered_data[filtered_data['감독'].str.contains(director, na=False)]
    if year:
        filtered_data = filtered_data[filtered_data['개봉일'].astype(str).str.contains(year, na=False)]

    if movie_title:
        if movie_title not in data['영화명'].values:
            # 유클리드 거리 계산 없이 가장 유사한 영화명 추천
            tfidf_title = tfidf.transform([tokenize_and_lemmatize(movie_title)])
            euclidean_dist_title = euclidean_distances(tfidf_title, tfidf_matrix)
            dist_scores = list(enumerate(euclidean_dist_title[0]))
            dist_scores = sorted(dist_scores, key=lambda x: x[1])
            dist_scores = dist_scores[:5]
            movie_indices = [i[0] for i in dist_scores]
            recommendations = data.iloc[movie_indices]

            # 시각화를 위한 거리 점수 포함
            distance_scores = [i[1] for i in dist_scores]
            return recommendations[['영화명', '장르', '감독', '개봉일']].values.tolist(), distance_scores
        else:
            # 영화명에 해당하는 인덱스 가져오기
            idx = data[data['영화명'] == movie_title].index[0]

            # 필터링된 데이터 내에서 영화명과 유사한 영화들을 추천하기 위해 유클리드 거리 계산
            filtered_indices = filtered_data.index
            dist_scores = []
            for filtered_idx in filtered_indices:
                if filtered_idx == idx:
                    continue  # 자기 자신은 제외
                dist_score = euclidean_dist[idx, filtered_idx]
                dist_scores.append((filtered_idx, dist_score))

            # 거리 순으로 정렬
            dist_scores = sorted(dist_scores, key=lambda x: x[1])

            # 상위 5개 추천
            dist_scores = dist_scores[:5]
            movie_indices = [i[0] for i in dist_scores]
            recommendations = data.iloc[movie_indices]

            # 시각화를 위한 거리 점수 포함
            distance_scores = [i[1] for i in dist_scores]
            return recommendations[['영화명', '장르', '감독', '개봉일']].values.tolist(), distance_scores

    else:
        # 필터링된 영화에서 상위 5개 선택
        recommendations = filtered_data.head(5)
        distance_scores = [0] * len(recommendations)  # 필터링된 결과에서는 거리 점수를 0으로 설정

    recommendations = recommendations.copy()
    # recommendations.loc[:, '개봉일'] = recommendations['개봉일'].astype(int)
    return recommendations[['영화명', '장르', '감독', '개봉일']].values.tolist(), distance_scores

# 사용자 입력을 통한 영화명, 장르, 감독, 제작 연도 입력
user_input = input("영화명, 장르, 감독, 제작 연도를 쉼표로 구분하여 입력하세요 (예: 제목,장르,국가,연도): ").strip()

# 입력된 값을 쉼표로 구분하여 리스트로 변환
inputs = [i.strip() if i.strip() else None for i in user_input.split(',')]
movie_title, genre, director, year = inputs + [None] * (4 - len(inputs))

recommended_movies, distance_scores = get_recommendations(movie_title, genre, director, year)
print("추천된 영화들:\n", recommended_movies)

# # 추천된 영화 목록과 거리 점수를 시각화
# def visualize_recommendations(recommended_movies, distance_scores):
#     # 추천된 영화 목록을 데이터프레임으로 변환
#     df = pd.DataFrame(recommended_movies, columns=['영화명', '장르', '감독', '개봉일'])
#     df["거리 점수"] = distance_scores

#     # 바 차트 생성
#     plt.figure(figsize=(12, 6))
#     plt.barh(df["영화명"], df["거리 점수"], color='skyblue')
#     plt.xlabel('거리 점수')
#     plt.title('영화 추천 거리 점수')
#     plt.gca().invert_yaxis()  # 영화명이 위에서 아래로 표시되도록 순서 뒤집기
#     for i, (title, score) in enumerate(zip(df["영화명"], df["거리 점수"])):
#         plt.text(score, i, f'{score:.2f}', va='center')
#     plt.show()
# Out:
# 영화 제목, 장르, 감독, 제작 연도를 쉼표로 구분하여 입력하세요 (예: 제목,장르,국가,연도): 범죄도시
# 추천된 영화들:
#  [['범죄도시', '범죄, 액션, 스릴러, 느와르, 블랙 코미디, 형사', '강윤성', ''], ['나쁜 녀석들: 더 무비', '', '', ''], ['범죄와의 전쟁: 나쁜놈들 전성시대', '범죄, 드라마, 느와르, 액션, 블랙 코미디, 시대극, 피카레스크', '윤종빈', ''], ['작전', '범죄, 스릴러, 코미디, 피카레스크', '이호재', ''], ['나쁜 녀석들: 포에버', '액션, 코미디, 범죄', '아딜 엘아르비빌랄 팔라', '']]

# %%
# 코사인 유사도 행렬 계산
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

def get_recommendations(movie_title=None, genre=None, director=None, year=None, genre_weight=1.0, director_weight=1.0, year_weight=1.0, cosine_sim=cosine_sim):
    if not movie_title and not genre and not director and not year:
        return "영화명, 장르, 감독 또는 제작 연도 중 하나를 입력하세요."

    filtered_data = data.copy()

    if movie_title:
        if movie_title not in data['영화명'].values:
            # 코사인 유사도 계산 없이 가장 유사한 영화명 추천
            tfidf_title = tfidf.transform([tokenize_and_lemmatize(movie_title)])
            cosine_sim_title = linear_kernel(tfidf_title, tfidf_matrix)
            sim_scores = list(enumerate(cosine_sim_title[0]))

            # 가중치 적용
            for i, (idx, score) in enumerate(sim_scores):
                genre_score = genre_weight if genre and genre in data.loc[idx, '장르'] else 0
                director_score = director_weight if director and director in data.loc[idx, '감독'] else 0
                year_score = year_weight if year and year in str(data.loc[idx, '개봉일']) else 0
                sim_scores[i] = (idx, score + genre_score + director_score + year_score)

            sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
            sim_scores = sim_scores[:5]
            movie_indices = [i[0] for i in sim_scores]
            recommendations = data.iloc[movie_indices]

            # 시각화를 위한 유사도 점수 포함
            similarity_scores = [i[1] for i in sim_scores]
            return recommendations[['영화명', '장르', '감독', '개봉일']].values.tolist(), similarity_scores
        else:
            # 영화명에 해당하는 인덱스 가져오기
            idx = data[data['영화명'] == movie_title].index[0]

            # 필터링된 데이터 내에서 영화명과 유사한 영화들을 추천하기 위해 코사인 유사도 계산
            filtered_indices = filtered_data.index
            sim_scores = []
            for filtered_idx in filtered_indices:
                if filtered_idx == idx:
                    continue  # 자기 자신은 제외
                sim_score = cosine_sim[idx, filtered_idx]

                # 가중치 적용
                genre_score = genre_weight if genre and genre in data.loc[filtered_idx, '장르'] else 0
                director_score = director_weight if director and director in data.loc[filtered_idx, '감독'] else 0
                year_score = year_weight if year and year in str(data.loc[filtered_idx, '개봉일']) else 0
                sim_scores.append((filtered_idx, sim_score + genre_score + director_score + year_score))

            # 유사도 순으로 정렬
            sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

            # 상위 5개 추천
            sim_scores = sim_scores[:5]
            movie_indices = [i[0] for i in sim_scores]
            recommendations = data.iloc[movie_indices]

            # 시각화를 위한 유사도 점수 포함
            similarity_scores = [i[1] for i in sim_scores]
            return recommendations[['영화명', '장르', '감독', '개봉일']].values.tolist(), similarity_scores

    else:
        # 필터링된 영화에서 상위 5개 선택
        recommendations = filtered_data.head(5)
        similarity_scores = [1] * len(recommendations)  # 필터링된 결과에서는 유사도 점수를 1로 설정

    recommendations = recommendations.copy()
    recommendations.loc[:, '개봉일'] = recommendations['개봉일'].astype(int)
    return recommendations[['영화명', '장르', '감독', '개봉일']].values.tolist(), similarity_scores

# 사용자 입력을 통한 영화명, 장르, 감독, 제작 연도 입력
user_input = input("'영화명', '장르', '감독', '개봉일'를 쉼표로 구분하여 입력하세요 (예: 제목,장르,국가,연도): ").strip()

# 입력된 값을 쉼표로 구분하여 리스트로 변환
inputs = [i.strip() if i.strip() else None for i in user_input.split(',')]
inputs = inputs + [None] * (4 - len(inputs))  # 입력된 값의 개수가 4개가 되도록 보충
movie_title, genre, director, year = inputs

# 사용자로부터 가중치 입력받기
genre_weight = float(input("장르 가중치 (기본값 1.0): ") or 1.0)
director_weight = float(input("국가 가중치 (기본값 1.0): ") or 1.0)
year_weight = float(input("연도 가중치 (기본값 1.0): ") or 1.0)

recommended_movies, similarity_scores = get_recommendations(movie_title, genre, director, year, genre_weight, director_weight, year_weight)
print("추천된 영화들:\n", recommended_movies)

# # 추천된 영화 목록과 유사도 점수를 시각화
# def visualize_recommendations(recommended_movies, similarity_scores):
#     # 추천된 영화 목록을 데이터프레임으로 변환
#     df = pd.DataFrame(recommended_movies, columns=['영화명', '장르', '감독', '개봉일'])
#     df["유사도 점수"] = similarity_scores

#     # 바 차트 생성
#     plt.figure(figsize=(12, 6))
#     plt.barh(df["영화명"], df["유사도 점수"], color='skyblue')
#     plt.xlabel('유사도 점수')
#     plt.title('영화 추천 유사도 점수')
#     plt.gca().invert_yaxis()  # 영화명이 위에서 아래로 표시되도록 순서 뒤집기
#     for i, (title, score) in enumerate(zip(df["영화명], df["유사도 점수"])):
#         plt.text(score, i, f'{score:.2f}', va='center')
#     plt.show()

# visualize_recommendations(recommended_movies, similarity_scores)
# Out:
# '영화명', '장르', '감독', '개봉일'를 쉼표로 구분하여 입력하세요 (예: 제목,장르,국가,연도): 범죄도시
# 장르 가중치 (기본값 1.0): 3
# 국가 가중치 (기본값 1.0): 0
# 연도 가중치 (기본값 1.0): 0
# 추천된 영화들:
#  [['범죄도시', '범죄, 액션, 스릴러, 느와르, 블랙 코미디, 형사', '강윤성', ''], ['나쁜 녀석들: 더 무비', '', '', ''], ['범죄와의 전쟁: 나쁜놈들 전성시대', '범죄, 드라마, 느와르, 액션, 블랙 코미디, 시대극, 피카레스크', '윤종빈', ''], ['작전', '범죄, 스릴러, 코미디, 피카레스크', '이호재', ''], ['나쁜 녀석들: 포에버', '액션, 코미디, 범죄', '아딜 엘아르비빌랄 팔라', '']]

# %%
# 처리된 텍스트 데이터 벡터화
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(data['Processed_Text'])

# 코사인 유사도 행렬 계산
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

def get_recommendations(movie_title=None, genre=None, director=None, year=None, cosine_sim=cosine_sim):
    if not movie_title and not genre and not director and not year:
        return "영화명, 장르, 감독 또는 제작 연도 중 하나를 입력하세요."

    filtered_data = data.copy()

    weights = {'genre_weight': 1.0, 'director_weight': 1.0, 'year_weight': 1.0}
    entered_criteria = 0

    # 입력된 조건에 대해 높은 가중치 부여
    if genre:
        weights['genre_weight'] = 2.0
        entered_criteria += 1
    if director:
        weights['director_weight'] = 2.0
        entered_criteria += 1
    if year:
        weights['year_weight'] = 2.0
        entered_criteria += 1

    # 입력되지 않은 조건에 대해 기본 가중치 부여
    if entered_criteria > 0:
        equal_weight = 1.0 / entered_criteria
    else:
        equal_weight = 1.0

    for key in weights.keys():
        if weights[key] == 1.0:
            weights[key] = equal_weight

    if movie_title:
        if movie_title not in data['영화명'].values:
            # 코사인 유사도 계산 없이 가장 유사한 영화명 추천
            tfidf_title = tfidf.transform([tokenize_and_lemmatize(movie_title)])
            cosine_sim_title = linear_kernel(tfidf_title, tfidf_matrix)
            sim_scores = list(enumerate(cosine_sim_title[0]))

            # 가중치 적용
            for i, (idx, score) in enumerate(sim_scores):
                genre_score = weights['genre_weight'] if genre and genre in data.loc[idx, 'genre'] else 0
                director_score = weights['director_weight'] if director and director in data.loc[idx, 'director_of_production'] else 0
                year_score = weights['year_weight'] if year and year in str(data.loc[idx, 'year_of_production']) else 0
                sim_scores[i] = (idx, score + genre_score + director_score + year_score)

            sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
            sim_scores = sim_scores[:5]
            movie_indices = [i[0] for i in sim_scores]
            recommendations = data.iloc[movie_indices]

            # 시각화를 위한 유사도 점수 포함
            similarity_scores = [i[1] for i in sim_scores]
            return recommendations[['영화명', '장르', '감독', '개봉일']].values.tolist(), similarity_scores
        else:
            # 영화명에 해당하는 인덱스 가져오기
            idx = data[data['영화명'] == movie_title].index[0]

            # 필터링된 데이터 내에서 영화명과 유사한 영화들을 추천하기 위해 코사인 유사도 계산
            filtered_indices = filtered_data.index
            sim_scores = []
            for filtered_idx in filtered_indices:
                if filtered_idx == idx:
                    continue  # 자기 자신은 제외
                sim_score = cosine_sim[idx, filtered_idx]

                # 가중치 적용
                genre_score = weights['genre_weight'] if genre and genre in data.loc[filtered_idx, 'genre'] else 0
                director_score = weights['director_weight'] if director and director in data.loc[filtered_idx, 'director_of_production'] else 0
                year_score = weights['year_weight'] if year and year in str(data.loc[filtered_idx, 'year_of_production']) else 0
                sim_scores.append((filtered_idx, sim_score + genre_score + director_score + year_score))

            # 유사도 순으로 정렬
            sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

            # 상위 5개 추천
            sim_scores = sim_scores[:5]
            movie_indices = [i[0] for i in sim_scores]
            recommendations = data.iloc[movie_indices]

            # 시각화를 위한 유사도 점수 포함
            similarity_scores = [i[1] for i in sim_scores]
            return recommendations[['영화명', '장르', '감독', '개봉일']].values.tolist(), similarity_scores

    else:
        # 필터링된 영화에서 상위 5개 선택
        recommendations = filtered_data.head(5)
        similarity_scores = [1] * len(recommendations)  # 필터링된 결과에서는 유사도 점수를 1로 설정

    recommendations = recommendations.copy()
    # recommendations.loc[:, 'year_of_production'] = recommendations['year_of_production'].astype(int)
    return recommendations[['영화명', '장르', '감독', '개봉일']].values.tolist(), similarity_scores

# 사용자 입력을 통한 영화명, 장르, 감독, 제작 연도 입력
user_input = input("영화명, 장르, 감독, 제작 연도를 쉼표로 구분하여 입력하세요 (예: 제목,장르,국가,연도): ").strip()

# 입력된 값을 쉼표로 구분하여 리스트로 변환
inputs = [i.strip() if i.strip() else None for i in user_input.split(',')]
inputs = inputs + [None] * (4 - len(inputs))  # 입력된 값의 개수가 4개가 되도록 보충
movie_title, genre, director, year = inputs

recommended_movies, similarity_scores = get_recommendations(movie_title, genre, director, year)
print("추천된 영화들:\n", recommended_movies)

# 추천된 영화 목록과 유사도 점수를 시각화
# def visualize_recommendations(recommended_movies, similarity_scores):
#     # 추천된 영화 목록을 데이터프레임으로 변환
#     df = pd.DataFrame(recommended_movies, columns=["영화명", "장르", "감독", "제작 연도"])
#     df["유사도 점수"] = similarity_scores

#     # 바 차트 생성
#     plt.figure(figsize=(12, 6))
#     plt.barh(df["영화명"], df["유사도 점수"], color='skyblue')
#     plt.xlabel('유사도 점수')
#     plt.title('영화 추천 유사도 점수')
#     plt.gca().invert_yaxis()  # 영화명이 위에서 아래로 표시되도록 순서 뒤집기
#     for i, (title, score) in enumerate(zip(df["영화명"], df["유사도 점수"])):
#         plt.text(score, i, f'{score:.2f}', va='center')
#     plt.show()

# visualize_recommendations(recommended_movies, similarity_scores)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c35777d42964> in <cell line: 2>()
#       1 # 처리된 텍스트 데이터 벡터화
# ----> 2 tfidf = TfidfVectorizer()
#       3 tfidf_matrix = tfidf.fit_transform(data['Processed_Text'])
#       4
#       5 # 코사인 유사도 행렬 계산
#
# NameError: name 'TfidfVectorizer' is not defined
